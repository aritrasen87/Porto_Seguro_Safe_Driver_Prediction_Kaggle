# %%
from __future__ import print_function

from datetime import datetime
import numpy as np
import pandas as pd
import optuna
import lightgbm as lgb
from path import Path
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
class Config:
    input_path = Path('/kaggle/input/porto-seguro-safe-driver-prediction')
    optuna_lgb = True
    n_estimators = 1500
    early_stopping_round = 150
    cv_folds = 5
    random_state = 0
    params = {
        'objective' : 'binary',
        'boosting_type' : 'gbdt',
        'learning_rate' : 0.01 ,
        'max_bin' : 25 ,
        'num_leaves' : 31,
        'min_child_samples' : 1500,
        'colsample_bytree' : 0.7,
        'subsample_freq' : 1,
        'subsample' : 0.7,
        'reg_alpha' : 1.0,
        'reg_lambda' : 1.0,
        'verbosity' : 0,
        'random_state' : 0
    }
config = Config()

# %%
train = pd.read_csv(config.input_path / 'train.csv',index_col='id')
test = pd.read_csv(config.input_path / 'test.csv',index_col='id')
submission = pd.read_csv(config.input_path / 'sample_submission.csv',index_col='id')

calc_features = [col for col in train.columns if '_calc' in col]
cat_features = [col for col in train.columns if '_cat' in col]

# %%
target = train['target']
train = train.drop(columns = 'target',axis='columns')

# %%
train = train.drop(columns = calc_features , axis = 'columns')
test = test.drop(columns = calc_features , axis = 'columns')

# %%
train = pd.get_dummies(train, columns=cat_features)
test = pd.get_dummies(test, columns=cat_features)

assert((train.columns==test.columns).all())

# %%
from numba import jit

@jit
def eval_gini(y_true,y_pred):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    
    ntrue = 0
    gini = 0
    delta = 0
    n = len(y_true)
    
    for i in range(n-1 , -1 , -1):
        y_i = y_true[i]
        ntrue += y_i
        gini += y_i * delta
        delta += 1 - y_i
    gini = 1 - 2 * gini / (ntrue * (n - ntrue))
    return gini

def gini_lgb(y_true,y_pred):
    eval_name = 'normalized_gini_coef'
    eval_result = eval_gini(y_true,y_pred)
    is_higher_better = True
    return eval_name, eval_result , is_higher_better

# %%
config.params
# Out:
# {'objective': 'binary',
#  'boosting_type': 'gbdt',
#  'learning_rate': 0.01,
#  'max_bin': 25,
#  'num_leaves': 31,
#  'min_child_samples': 1500,
#  'colsample_bytree': 0.7,
#  'subsample_freq': 1,
#  'subsample': 0.7,
#  'reg_alpha': 1.0,
#  'reg_lambda': 1.0,
#  'verbosity': 0,
#  'random_state': 0}

# %%
if config.optuna_lgb:
    
    def objective(trial):
        params = {
            'learning_rate' : trial.suggest_float("learning_rate",0.01 , 1) ,
            'num_leaves' : trial.suggest_int("num_leaves",3,255),
            'min_child_samples' : trial.suggest_int("min_child_samples",3,3000),
            'colsample_bytree' : trial.suggest_float("colsample_bytree",0.1,1),
            'subsample_freq' : trial.suggest_int("subsample_freq",0,10),
            'subsample' : trial.suggest_float("subsample",0.1,1),
            'reg_alpha' : trial.suggest_loguniform("reg_alpha",1e-9,10.0),
            'reg_lambda' : trial.suggest_loguniform("reg_lambda",1e-9,10.0)
        }
        score = list()
        skf = StratifiedKFold(n_splits=config.cv_folds,shuffle=True,random_state=config.random_state)
        
        for train_idx , valid_idx in skf.split(train,target):
            X_train = train.iloc[train_idx]
            y_train = target.iloc[train_idx]
            X_valid = train.iloc[valid_idx]
            y_valid = target.iloc[valid_idx]
            
            model = lgb.LGBMClassifier(**params , n_estimators=1500 , early_stopping_round=150 , force_row_wise=True)
            
            callbacks = [lgb.early_stopping(stopping_rounds=150 , verbose=False)]
            
            model.fit(X_train,y_train, eval_set=[(X_valid,y_valid)] , eval_metric=gini_lgb , callbacks=callbacks)
            
            score.append(model.best_score_['valid_0']['normalized_gini_coef'])
        return np.mean(score)
    study = optuna.create_study(direction="maximize")
    study.optimize(objective,n_trials=300)
    print('Best Normalized Score:',study.best_value)
    print('Best Params:',study.best_params)
    
    params = {
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbosity': 0,
        'random_state': 0
    }
    
    params.update(study.best_params)
    
else:
    params = config.params
# Out:
# [I 2023-03-04 12:01:37,612] A new study created in memory with name: no-name-8e3c5ff9-1e22-4598-8e2d-3e356fecefb6
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:03:08,066] Trial 0 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.6150706204467805, 'num_leaves': 112, 'min_child_samples': 989, 'colsample_bytree': 0.38612092204647486, 'subsample_freq': 4, 'subsample': 0.6840317979177926, 'reg_alpha': 4.409308050298407e-07, 'reg_lambda': 5.164897153198387e-07}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:05:03,160] Trial 1 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.08087411762189872, 'num_leaves': 186, 'min_child_samples': 2646, 'colsample_bytree': 0.9599222068210076, 'subsample_freq': 2, 'subsample': 0.931127084933912, 'reg_alpha': 1.6489861702118042e-09, 'reg_lambda': 0.006969468085630522}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:05:34,681] Trial 2 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.9611893231308278, 'num_leaves': 155, 'min_child_samples': 1985, 'colsample_bytree': 0.20535081473503766, 'subsample_freq': 6, 'subsample': 0.125281585423569, 'reg_alpha': 4.368019623630654e-09, 'reg_lambda': 0.015497993988087069}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:06:28,274] Trial 3 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.7417181056241497, 'num_leaves': 239, 'min_child_samples': 1551, 'colsample_bytree': 0.11126777670958653, 'subsample_freq': 8, 'subsample': 0.4870227344870679, 'reg_alpha': 0.12493562440661282, 'reg_lambda': 0.038484391931237746}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:08:05,485] Trial 4 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.9518303080894678, 'num_leaves': 142, 'min_child_samples': 387, 'colsample_bytree': 0.16061875012416524, 'subsample_freq': 2, 'subsample': 0.7926053290077733, 'reg_alpha': 0.2031169635366365, 'reg_lambda': 3.84428153733436e-06}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:09:40,606] Trial 5 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.8244909061727652, 'num_leaves': 176, 'min_child_samples': 1010, 'colsample_bytree': 0.224209448577532, 'subsample_freq': 0, 'subsample': 0.9659389086960476, 'reg_alpha': 2.040593854983573e-05, 'reg_lambda': 4.564041267361108}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:10:50,593] Trial 6 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.6405868973428663, 'num_leaves': 201, 'min_child_samples': 1359, 'colsample_bytree': 0.23575676044302074, 'subsample_freq': 8, 'subsample': 0.43052961097552145, 'reg_alpha': 2.562820454024509e-07, 'reg_lambda': 4.835447691564747e-06}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:12:14,599] Trial 7 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.7956550066025821, 'num_leaves': 75, 'min_child_samples': 2544, 'colsample_bytree': 0.9875655192696308, 'subsample_freq': 5, 'subsample': 0.8542434479567179, 'reg_alpha': 5.174768904901069e-08, 'reg_lambda': 8.24143617850265e-07}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12
finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.7004017640241353, 'num_leaves': 155, 'min_child_samples': 1388, 'colsample_bytree': 0.1189118965945592, 'subsample_freq': 7, 'subsample': 0.5340890932895236, 'reg_alpha': 1.7723714084358586e-07, 'reg_lambda': 0.007626967785352931}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:42:42,712] Trial 31 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.9469908489300805, 'num_leaves': 243, 'min_child_samples': 1206, 'colsample_bytree': 0.16564672022179924, 'subsample_freq': 8, 'subsample': 0.8154608980053357, 'reg_alpha': 0.0008069005897690825, 'reg_lambda': 0.12104621044758354}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:43:44,394] Trial 32 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.765672587000858, 'num_leaves': 230, 'min_child_samples': 1487, 'colsample_bytree': 0.18191684308955547, 'subsample_freq': 9, 'subsample': 0.4618071753402642, 'reg_alpha': 0.3631288838828885, 'reg_lambda': 0.592430873432041}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:45:25,942] Trial 33 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.80024002480045, 'num_leaves': 181, 'min_child_samples': 290, 'colsample_bytree': 0.2520389675688352, 'subsample_freq': 1, 'subsample': 0.6082329511290413, 'reg_alpha': 0.03651415017216629, 'reg_lambda': 3.1794307898942025}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:47:10,819] Trial 34 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.8717463939996746, 'num_leaves': 252, 'min_child_samples': 2417, 'colsample_bytree': 0.2515049185204902, 'subsample_freq': 5, 'subsample': 0.9461417471448664, 'reg_alpha': 8.93575915432477e-06, 'reg_lambda': 0.023026512295580656}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:48:23,472] Trial 35 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.5976986399571544, 'num_leaves': 207, 'min_child_samples': 1562, 'colsample_bytree': 0.10581653006399344, 'subsample_freq': 9, 'subsample': 0.7242678864357056, 'reg_alpha': 7.451564412240511e-07, 'reg_lambda': 0.16837838538679917}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:49:42,766] Trial 36 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.9973850939491895, 'num_leaves': 138, 'min_child_samples': 2810, 'colsample_bytree': 0.1914721859958548, 'subsample_freq': 4, 'subsample': 0.809891958918923, 'reg_alpha': 4.3434484696488604e-05, 'reg_lambda': 0.0020550279151295005}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:51:16,180] Trial 37 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.8120821029255543, 'num_leaves': 166, 'min_child_samples': 1995, 'colsample_bytree': 0.2266602250473019, 'subsample_freq': 0, 'subsample': 0.4755865408319463, 'reg_alpha': 0.00019611082344820116, 'reg_lambda': 4.919514495312767e-05}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:52:46,505] Trial 38 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.6896076906698202, 'num_leaves': 108, 'min_child_samples': 1118, 'colsample_bytree': 0.16018147613196307, 'subsample_freq': 2, 'subsample': 0.7628254832414691, 'reg_alpha': 3.061596934833986e-09, 'reg_lambda': 0.011457713966298069}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:53:57,317] Trial 39 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.7429488368554591, 'num_leaves': 195, 'min_child_samples': 1337, 'colsample_bytree': 0.31404505289750745, 'subsample_freq': 6, 'subsample': 0.3964663497684062, 'reg_alpha': 1.543586300004723e-08, 'reg_lambda': 0.0011625326792801466}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:55:00,962] Trial 40 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.828937660689386, 'num_leaves': 83, 'min_child_samples': 499, 'colsample_bytree': 0.39175875385637066, 'subsample_freq': 3, 'subsample': 0.3002666026345562, 'reg_alpha': 2.3717811794237345e-06, 'reg_lambda': 0.03208347029095736}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 12:56:14,143] Trial 41 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0
finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.3217136762513665, 'num_leaves': 11, 'min_child_samples': 2000, 'colsample_bytree': 0.31860065388443787, 'subsample_freq': 10, 'subsample': 0.5570873295489733, 'reg_alpha': 0.12793422921485958, 'reg_lambda': 0.00011256360043634703}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 18:32:55,904] Trial 293 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.16947554047287466, 'num_leaves': 130, 'min_child_samples': 1841, 'colsample_bytree': 0.9140088507474271, 'subsample_freq': 3, 'subsample': 0.5960188679599647, 'reg_alpha': 0.0003488193564981072, 'reg_lambda': 0.00785050281221127}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 18:33:43,275] Trial 294 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.6467362123906842, 'num_leaves': 226, 'min_child_samples': 1520, 'colsample_bytree': 0.7443102587317971, 'subsample_freq': 4, 'subsample': 0.194929372128221, 'reg_alpha': 8.645015772155135e-06, 'reg_lambda': 2.033999936808065e-06}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 18:35:17,294] Trial 295 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.055586039744454245, 'num_leaves': 105, 'min_child_samples': 278, 'colsample_bytree': 0.47930222211238194, 'subsample_freq': 6, 'subsample': 0.8740034791423029, 'reg_alpha': 0.6814629992114543, 'reg_lambda': 3.971481868932225e-07}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 18:36:51,815] Trial 296 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.8840543026865452, 'num_leaves': 147, 'min_child_samples': 1718, 'colsample_bytree': 0.9419978893643612, 'subsample_freq': 4, 'subsample': 0.6412860661123656, 'reg_alpha': 4.076520154260213, 'reg_lambda': 8.346284664258034e-08}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 18:38:41,762] Trial 297 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.6758952809384239, 'num_leaves': 172, 'min_child_samples': 982, 'colsample_bytree': 0.5231919011709212, 'subsample_freq': 5, 'subsample': 0.8405927149169677, 'reg_alpha': 4.7256919214330816e-07, 'reg_lambda': 0.0007060100823351914}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 18:40:04,782] Trial 298 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.3026886789749579, 'num_leaves': 92, 'min_child_samples': 629, 'colsample_bytree': 0.34998888082900637, 'subsample_freq': 1, 'subsample': 0.4969747046258717, 'reg_alpha': 1.571213747235031e-09, 'reg_lambda': 5.570817313323195e-07}. Best is trial 0 with value: -0.0005706231819715413.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if sys.path[0] == "":
# [I 2023-03-04 18:40:58,016] Trial 299 finished with value: -0.0005706231819715413 and parameters: {'learning_rate': 0.836212690063094, 'num_leaves': 38, 'min_child_samples': 1955, 'colsample_bytree': 0.2800606753996706, 'subsample_freq': 9, 'subsample': 0.6694355561576829, 'reg_alpha': 0.007861017031921732, 'reg_lambda': 0.0993858919732935}. Best is trial 0 with value: -0.0005706231819715413.
# Best Normalized Score: -0.0005706231819715413
# Best Params: {'learning_rate': 0.6150706204467805, 'num_leaves': 112, 'min_child_samples': 989, 'colsample_bytree': 0.38612092204647486, 'subsample_freq': 4, 'subsample': 0.6840317979177926, 'reg_alpha': 4.409308050298407e-07, 'reg_lambda': 5.164897153198387e-07}

# %%
params
# Out:
# {'objective': 'binary',
#  'boosting_type': 'gbdt',
#  'verbosity': 0,
#  'random_state': 0,
#  'learning_rate': 0.6150706204467805,
#  'num_leaves': 112,
#  'min_child_samples': 989,
#  'colsample_bytree': 0.38612092204647486,
#  'subsample_freq': 4,
#  'subsample': 0.6840317979177926,
#  'reg_alpha': 4.409308050298407e-07,
#  'reg_lambda': 5.164897153198387e-07}
